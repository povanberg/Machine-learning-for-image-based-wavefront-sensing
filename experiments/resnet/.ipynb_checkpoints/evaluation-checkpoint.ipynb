# %%
import sys
import torch
from collections import OrderedDict
from model_resnet import Net
sys.path.insert(0, '../../')
from visualization import *
from dataset import *

# %%
# Import validation dataset (size 1000 images)
data_dir = '../../dataset/validation/'
dataset_size = 100
dataset = psf_dataset(root_dir = data_dir, size = dataset_size,
                      transform = transforms.Compose([Normalize(data_dir),ToTensor()]))

# %%
model = Net()
model.eval()

# Load weights
model_dir = 'model.pth'
state_dict = torch.load(model_dir)
new_state_dict = OrderedDict()
for k, v in state_dict.items():
    name = k[7:] # remove module.
    new_state_dict[name] = v
model.load_state_dict(new_state_dict)

# %%
visualize(dataset, model)
# Out:
# confParse.py -> calcParams: Overriding sci FOV with pxlscale
# Dataset Sample: Illustration with 3 random point spread functions
# Input:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2f18a57bb20d> in <module>()
# ----> 1 visualize(dataset, model)
#
# ~/phase-retrieval2/visualization.py in visualize(dataset, model)
#      89     for i in range(n):
#      90         axarr[i].imshow(phase_in[i], cmap=plt.cm.jet)
# ---> 91         axarr[i].title('Corresponding phase: %f nm (rms error)' % (rms_wfe(phase_in[i])))
#      92     plt.show()
#      93
#
# TypeError: 'Text' object is not callable

# %%
import numpy as np
rms_wfe(np.ones(shape=(128,128)))
