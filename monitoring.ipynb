# %%
from monitoring import *

# %%
plotMetrics('experiments/inception/monitoring_metrics.json','temperatures',limit=93)

# %%
plotMetrics('experiments/inception/monitoring_metrics.json','fanSpeed',limit=None)

# %%
plotMetrics('experiments/inception/monitoring_metrics.json','power',limit=250)
